# %%
import numpy as np
import pandas as pd
import geopandas as gpd 
import matplotlib 
import matplotlib.pyplot as plt
#from geopandas import GeoDataFrame

# %%
edudata = pd.read_csv('EducationCountriesData.csv')

# %%
edudata.head()
# Out:
#   Country Name Country Code  \
# 0       Brazil          BRA
# 1       Brazil          BRA
# 2       Brazil          BRA
# 3       Brazil          BRA
# 4       Brazil          BRA
#
#                                               Series     Series Code  \
# 0  Adjusted net enrolment rate, lower secondary, ...      UIS.NERA.2
# 1  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.F
# 2  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.GPI
# 3  Adjusted net enrolment rate, lower secondary, ...    UIS.NERA.2.M
# 4  Adjusted net enrolment rate, primary, both sex...     SE.PRM.TENR
#
#   2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 0            ..      74.37345      72.57631      82.47292      82.20258
# 1            ..      77.78973      75.84541      86.56209      86.61052
# 2            ..       1.09445       1.09225       1.10078        1.1088
# 3            ..      71.07662      69.43952      78.63671      78.11206
# ...

# %%
edudata[edudata['Series Code']=='UIS.NERA.3.F']
# Out:
#      Country Name Country Code  \
# 9          Brazil          BRA
# 21           Chad          TCD
# 33         Norway          NOR
# 45        Senegal          SEN
# 57   South Africa          ZAF
# 69  United States          USA
#
#                                                Series   Series Code  \
# 9   Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 21  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 33  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 45  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 57  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 69  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 9             ..            ..            ..      65.53282      67.51686
# 21            ..            ..            ..            ..            ..
# ...

# %%
upperfemale = edudata[edudata['Series Code']== 'UIS.NERA.3.F']

# %%
upperfemale.head(6)
# Out:
#      Country Name Country Code  \
# 9          Brazil          BRA
# 21           Chad          TCD
# 33         Norway          NOR
# 45        Senegal          SEN
# 57   South Africa          ZAF
# 69  United States          USA
#
#                                                Series   Series Code  \
# 9   Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 21  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 33  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 45  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 57  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 69  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 9             ..            ..            ..      65.53282      67.51686
# 21            ..            ..            ..            ..            ..
# ...

# %%
uf2 = upperfemale[['Country Name', 'Country Code', 'Series', 'Series Code', 'Most Recent Year', 'MRY Year']].copy()

# %%
uf2.head(6)
# Out:
#      Country Name Country Code  \
# 9          Brazil          BRA
# 21           Chad          TCD
# 33         Norway          NOR
# 45        Senegal          SEN
# 57   South Africa          ZAF
# 69  United States          USA
#
#                                                Series   Series Code  \
# 9   Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 21  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 33  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 45  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 57  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
# 69  Adjusted net enrolment rate, upper secondary, ...  UIS.NERA.3.F
#
#     Most Recent Year  MRY Year
# 9           65.96073    2015.0
# 21           5.04451    2016.0
# 33          91.91552    2014.0
# 45          18.69854    2017.0
# 57          63.97142    2017.0
# 69          85.15784    2017.0

# %%
uf2.sort_values(by=['Most Recent Year'], ascending=False).plot.bar('Country Name', 'Most Recent Year')
plt.xlabel('Countries')
plt.ylabel('Education Rates (%)')
plt.title('Upper Secondary Female Education Rates')
plt.show()

# %%
edudata[edudata['Series Code']=='UIS.NERA.2.F']
# Out:
#      Country Name Country Code  \
# 1          Brazil          BRA
# 13           Chad          TCD
# 25         Norway          NOR
# 37        Senegal          SEN
# 49   South Africa          ZAF
# 61  United States          USA
#
#                                                Series   Series Code  \
# 1   Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 13  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 25  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 37  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 49  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 61  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 1             ..      77.78973      75.84541      86.56209      86.61052
# 13            ..            ..            ..            ..            ..
# ...

# %%
lowerfemale = edudata[edudata['Series Code']== 'UIS.NERA.2.F']

# %%
lowerfemale.head(6)
# Out:
#      Country Name Country Code  \
# 1          Brazil          BRA
# 13           Chad          TCD
# 25         Norway          NOR
# 37        Senegal          SEN
# 49   South Africa          ZAF
# 61  United States          USA
#
#                                                Series   Series Code  \
# 1   Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 13  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 25  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 37  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 49  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 61  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 1             ..      77.78973      75.84541      86.56209      86.61052
# 13            ..            ..            ..            ..            ..
# ...

# %%
lf2 = lowerfemale[['Country Name', 'Country Code', 'Series', 'Series Code', 'Most Recent Year', 'MRY Year']].copy()

# %%
lf2.head(6)
# Out:
#      Country Name Country Code  \
# 1          Brazil          BRA
# 13           Chad          TCD
# 25         Norway          NOR
# 37        Senegal          SEN
# 49   South Africa          ZAF
# 61  United States          USA
#
#                                                Series   Series Code  \
# 1   Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 13  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 25  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 37  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 49  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
# 61  Adjusted net enrolment rate, lower secondary, ...  UIS.NERA.2.F
#
#     Most Recent Year  MRY Year
# 1           85.98437    2015.0
# 13          12.34487    2016.0
# 25          99.55054    2014.0
# 37          40.59536    2017.0
# 49          64.30112    2017.0
# 61          89.42543    2017.0

# %%
lf2.sort_values(by=['Most Recent Year'], ascending=False).plot.bar('Country Name', 'Most Recent Year')
plt.xlabel('Countries')
plt.ylabel('Education Rates (%)')
plt.title('Lower Secondary Female Education Rates')
plt.show()

# %%
edudata[edudata['Series Code']=='SE.PRM.TENR.FE']
# Out:
#      Country Name Country Code  \
# 5          Brazil          BRA
# 17           Chad          TCD
# 29         Norway          NOR
# 41        Senegal          SEN
# 53   South Africa          ZAF
# 65  United States          USA
#
#                                               Series     Series Code  \
# 5   Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 17  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 29  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 41  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 53  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 65  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 5             ..      95.40211      99.27482      97.84479      97.61097
# 17            ..      54.04668            ..      67.41198            ..
# ...

# %%
prmfemale = edudata[edudata['Series Code']== 'SE.PRM.TENR.FE']

# %%
prmfemale.head(6)
# Out:
#      Country Name Country Code  \
# 5          Brazil          BRA
# 17           Chad          TCD
# 29         Norway          NOR
# 41        Senegal          SEN
# 53   South Africa          ZAF
# 65  United States          USA
#
#                                               Series     Series Code  \
# 5   Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 17  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 29  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 41  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 53  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 65  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
#
#    2010 [YR2010] 2011 [YR2011] 2012 [YR2012] 2013 [YR2013] 2014 [YR2014]  \
# 5             ..      95.40211      99.27482      97.84479      97.61097
# 17            ..      54.04668            ..      67.41198            ..
# ...

# %%
pf2 = prmfemale[['Country Name', 'Country Code', 'Series', 'Series Code', 'Most Recent Year', 'MRY Year']].copy()

# %%
pf2.head(6)
# Out:
#      Country Name Country Code  \
# 5          Brazil          BRA
# 17           Chad          TCD
# 29         Norway          NOR
# 41        Senegal          SEN
# 53   South Africa          ZAF
# 65  United States          USA
#
#                                               Series     Series Code  \
# 5   Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 17  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 29  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 41  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 53  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
# 65  Adjusted net enrolment rate, primary, female (%)  SE.PRM.TENR.FE
#
#     Most Recent Year  MRY Year
# 5           97.04205    2015.0
# 17          64.29745    2016.0
# 29          99.79021    2014.0
# 41          80.75965    2017.0
# 53          94.66547    2017.0
# 65          95.51193    2017.0

# %%
pf2.sort_values(by=['Most Recent Year'], ascending=False).plot.bar('Country Name', 'Most Recent Year')
plt.xlabel('Countries')
plt.ylabel('Education Rates (%)')
plt.title('Primary Female Education Rates')
plt.show()

# %%
fr = pd.read_csv('FertilityRatesCountriesData.csv')

# %%
fr.head(6)
# Out:
#     Country Name Country Code  \
# 0         Brazil          BRA
# 1           Chad          TCD
# 2         Norway          NOR
# 3        Senegal          SEN
# 4   South Africa          ZAF
# 5  United States          USA
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                            57.8858
# 1                                           157.9144
# 2                                             5.1048
# 3                                            70.7160
# 4                                            67.8488
# 5                                            18.5562
#
#    Fertility rate, total (births per woman)
# 0                                    1.7300
# 1                                    5.7470
# 2                                    1.6200
# 3                                    4.6250
# 4                                    2.4050
# 5                                    1.7295

# %%
afr = fr[['Country Name', 'Country Code', 'Adolescent fertility rate (births per 1,000 women ages 15-19)']].copy()

# %%
afr.head(10)
# Out:
#     Country Name Country Code  \
# 0         Brazil          BRA
# 1           Chad          TCD
# 2         Norway          NOR
# 3        Senegal          SEN
# 4   South Africa          ZAF
# 5  United States          USA
# 6            NaN          NaN
# 7            NaN          NaN
# 8            NaN          NaN
# 9            NaN          NaN
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)
# 0                                            57.8858
# 1                                           157.9144
# 2                                             5.1048
# 3                                            70.7160
# 4                                            67.8488
# 5                                            18.5562
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
afr_clean = afr.dropna(subset = ["Country Name"], inplace=True)
afr_clean = afr.dropna(subset = ["Country Code"], inplace=True)
afr_clean = afr.dropna(subset = ["Adolescent fertility rate (births per 1,000 women ages 15-19)"], inplace=True)

# %%
afr.head(10)
# Out:
#     Country Name Country Code  \
# 0         Brazil          BRA
# 1           Chad          TCD
# 2         Norway          NOR
# 3        Senegal          SEN
# 4   South Africa          ZAF
# 5  United States          USA
#
#    Adolescent fertility rate (births per 1,000 women ages 15-19)
# 0                                            57.8858
# 1                                           157.9144
# 2                                             5.1048
# 3                                            70.7160
# 4                                            67.8488
# 5                                            18.5562

# %%
afr.sort_values(by=['Adolescent fertility rate (births per 1,000 women ages 15-19)'], ascending=True).plot.bar('Country Name', 'Adolescent fertility rate (births per 1,000 women ages 15-19)')
plt.xlabel('Countries')
plt.ylabel('Ferility Rates (births per 1,000 women ages 15-19)')
plt.title('Adolescent Fertility Rates')
plt.show()

# %%
tfr = fr[['Country Name', 'Country Code', 'Fertility rate, total (births per woman)']].copy()

# %%
tfr.head(10)
# Out:
#     Country Name Country Code  Fertility rate, total (births per woman)
# 0         Brazil          BRA                                    1.7300
# 1           Chad          TCD                                    5.7470
# 2         Norway          NOR                                    1.6200
# 3        Senegal          SEN                                    4.6250
# 4   South Africa          ZAF                                    2.4050
# 5  United States          USA                                    1.7295
# 6            NaN          NaN                                       NaN
# 7            NaN          NaN                                       NaN
# 8            NaN          NaN                                       NaN
# 9            NaN          NaN                                       NaN

# %%
tfr_clean = tfr.dropna(subset = ["Country Name"], inplace=True)
tfr_clean = tfr.dropna(subset = ["Country Code"], inplace=True)
tfr_clean = tfr.dropna(subset = ["Fertility rate, total (births per woman)"], inplace=True)

# %%
tfr.head(10)
# Out:
#     Country Name Country Code  Fertility rate, total (births per woman)
# 0         Brazil          BRA                                    1.7300
# 1           Chad          TCD                                    5.7470
# 2         Norway          NOR                                    1.6200
# 3        Senegal          SEN                                    4.6250
# 4   South Africa          ZAF                                    2.4050
# 5  United States          USA                                    1.7295

# %%
tfr.sort_values(by=['Fertility rate, total (births per woman)'], ascending=True).plot.bar('Country Name', 'Fertility rate, total (births per woman)')
plt.xlabel('Countries')
plt.ylabel('Ferility Rates (births per woman)')
plt.title('Fertility Rates')
plt.show()
